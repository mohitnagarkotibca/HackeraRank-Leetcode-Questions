# %% [markdown]
# ## ![image.png](attachment:image.png)

# %%
#!/bin/python3
import math
import os
import random
import re
import sys

# Complete the aVeryBigSum function below.
def aVeryBigSum(ar):
    return int(sum(ar))


ar_count = int(input())

ar = list(map(int, input().rstrip().split()))

result = aVeryBigSum(ar)

print(result)
# Out:
# 4
# 123123123 123131231 1231313 1234234234
# 1481719901
