# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def sockMerchant(n, ar):
    uni= set(ar)
    li=[]
    for color in uni:
        li.append(math.floor(ar.count(color)/2))
    return sum(li)
        
sock=[10, 20, 20, 10, 10, 30, 50, 10, 20]
s1=[1,1,3,1,2,1,3,3,3,3]
sockMerchant(len(s1), s1)
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)
